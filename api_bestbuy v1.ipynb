# %%
import os
import json
import requests
import pandas as pd

from sqlalchemy import create_engine
from time import perf_counter, sleep
from datetime import datetime, timedelta

import config_bestbuy

# %%
def initialize(folder_index=0):

    folders = ['products', 'categories', 'stores', 'products_update']
    datename = datetime.utcnow().strftime('%Y%m%d')
    path = config_bestbuy.path
    foldername = f'best_buy_{datename}\\{folders[folder_index]}'
    folderpath = os.path.join(path, foldername)

    if not os.path.exists(folderpath):
        os.makedirs(folderpath)

    db = os.path.join(config_bestbuy.path, 'bestbuy.db')
    conn_string = f'sqlite:///{db}'
    engine = create_engine(conn_string)

    with engine.connect() as cnx:
        try:
            sel_stmt = "SELECT * FROM products LIMIT 0"
            df_db = pd.read_sql(sql=sel_stmt, con=cnx)
            db_cols = df_db.columns.tolist()
        except Exception as e:
            db_cols = []
            
    return folderpath, datename, engine, db_cols


def api_bestbuy(cursorMark="*", api_index=0, page_size=100, days=1):
    key = config_bestbuy.key_bestbuy
    yesterday = datetime.utcnow().date() - timedelta(days=days)
    apis = ['products', 'categories', 'stores', f'products(itemUpdateDate>{yesterday}&active=*)']
    url = f"https://api.bestbuy.com/v1/{apis[api_index]}"
    payload = {
        'apiKey': key, 
        'pageSize': page_size, 
        'format': 'json', 
        'show': 'all',
        'cursorMark': cursorMark
        }
    r = requests.get(f'{url}', params=payload)

    return r


def insert_db(r, engine, db_cols):

    with engine.connect() as cnx:
        # sel_stmt = "SELECT * FROM products LIMIT 0"
        # df_db = pd.read_sql(sql=sel_stmt, con=cnx)
        # db_cols = df_db.columns.tolist()

        io = r.json()
        df_meta = pd.DataFrame(io)
        df_meta = df_meta.iloc[:, :-1]
        df_products = pd.DataFrame(io['products'])
        df = df_meta.merge(df_products, how='inner', left_index=True, right_index=True)
        df.insert(0, 'request_timestamp', datetime.utcnow())

        for col in df.columns.tolist():
            if df[col].dtype == 'object' or df[col].dtype == 'int64':
                df[col] = df[col].astype('str')

            datatype = df[col].dtype
            if datatype == 'bool':
                datatype = 'INTEGER'
            if datatype == 'float64':
                datatype = 'REAL'
            elif datatype == 'datetime64[ns]':
                datatype = 'NUMERIC'
            else: # int64, object, TEXT
                datatype = 'TEXT'
            
            if col not in db_cols:
                alter_stmt = f"""
                ALTER TABLE products
                ADD {col} {datatype};
                """
                try:
                    cnx.execute(alter_stmt)
                except Exception as e:
                    # print(f'error: {e}\n{col} already exists')
                    print(f'error: {col} already exists')
                finally:
                    db_cols.append(col)
                
        df.to_sql(name='products', con=cnx, if_exists='append', index=False)


def main(api_index=0, page_size=100, days=1, db=False):

    t0 = perf_counter()
    folderpath, datename, engine, db_cols = initialize(folder_index=api_index)
    nextcursorMark = "*"
    pg = 0
    pages = api_bestbuy(cursorMark=nextcursorMark, api_index=api_index, page_size=page_size, days=days).json()['totalPages']
    print(f'{pages=}')
    sleep(1)
    t1 = perf_counter()

    while True:
        print(f'{pg=}', f'{nextcursorMark=}', f'{t1=}', f'{perf_counter()-t1=}', sep=' | ')

        r = api_bestbuy(cursorMark=nextcursorMark, api_index=api_index, page_size=page_size, days=days)

        if r.status_code == 200:
            try:
                if len(r.json()['products']) == 0:
                    print(f"fin: {(perf_counter()-t0)=}")
                    break      

                nextcursorMark = r.json()['nextCursorMark']
                pg += 1
            
            except (NameError, ValueError, KeyError) as e:
                print(f'{e=}')
                t1 = perf_counter()

            else:
                pass

            finally:
                pass
            
            filename = f'best_buy_{datename}_{pg:05}.json'
            filepath = os.path.join(folderpath, filename)

            with open(filepath, 'w') as f:
                json.dump(r.json(), f, indent=4)

            if db:
                insert_db(r=r, engine=engine, db_cols=db_cols)

        timer = perf_counter()-t1
        if (pg)%5==0:
            if timer<1:
                sleep(1-timer)
            t1 = perf_counter()

# %%
if __name__ == '__main__':

    # api_index = {0: 'products', 1: 'categories', 2: 'stores', 3: 'products(itemUpdateDate>today&active=*)'}
    main(api_index=0, page_size=100, days=2, db=True)
# Out:
# pages=2252
# pg=0 | nextcursorMark='*' | t1=33945.1970943 | perf_counter()-t1=2.720000338740647e-05
# error: utc_timestamp already exists
# error: nextCursorMark already exists
# error: total already exists
# error: totalPages already exists
# error: queryTime already exists
# error: totalTime already exists
# error: partial already exists
# error: canonicalUrl already exists
# error: sku already exists
# error: score already exists
# error: productId already exists
# error: name already exists
# error: source already exists
# error: type already exists
# error: startDate already exists
# error: new already exists
# error: active already exists
# error: lowPriceGuarantee already exists
# error: activeUpdateDate already exists
# error: regularPrice already exists
# error: salePrice already exists
# error: clearance already exists
# error: onSale already exists
# error: planPrice already exists
# error: priceWithPlan already exists
# error: contracts already exists
# error: priceRestriction already exists
# error: priceUpdateDate already exists
# error: digital already exists
# error: preowned already exists
# error: carriers already exists
# error: planFeatures already exists
# error: devices already exists
# error: carrierPlans already exists
# error: technologyCode already exists
# error: carrierModelNumber already exists
# error: earlyTerminationFees already exists
# error: monthlyRecurringCharge already exists
# error: monthlyRecurringChargeGrandTotal already exists
# error: activationCharge already exists
# error: minutePrice already exists
# error: planCategory already exists
# error: planType already exists
# error: familyIndividualCode already exists
# error: validFrom already exists
# error: validUntil already exists
# error: carrierPlan already exists
# error: outletCenter already exists
# error: secondaryMarket already exists
# error: frequentlyPurchasedWith already exists
# error: accessories already exists
# error: relatedProducts already exists
# error: requiredParts already exists
# error: techSupportPlans already exists
# error: crossSell already exists
# error: salesRankShortTerm already exists
# error: salesRankMediumTerm already exists
# error: salesRankLongTerm already exists
# error: bestSellingRank already exists
# error: url already exists
# error: spin360Url already exists
# error: mobileUrl already exists
# error: affiliateUrl already exists
# error: addToCartUrl already exists
# error: affiliateAddToCartUrl already exists
# error: linkShareAffiliateUrl already exists
# error: linkShareAffiliateAddToCartUrl already exists
# error: search already exists
# error: upc already exists
# error: productTemplate already exists
# error: categoryPath already exists
# error: alternateCategories already exists
# error: lists already exists
# error: customerReviewCount already exists
# error: customerReviewAverage already exists
# error: customerTopRated already exists
# error: format already exists
# error: freeShipping already exists
# error: freeShippingEligible already exists
# error: inStoreAvailability already exists
# error: inStoreAvailabilityText already exists
# error: inStoreAvailabilityTextHtml already exists
# error: inStoreAvailabilityUpdateDate already exists
# error: itemUpdateDate already exists
# error: onlineAvailability already exists
# error: onlineAvailabilityText already exists
# error: onlineAvailabilityTextHtml already exists
# error: onlineAvailabilityUpdateDate already exists
# error: releaseDate already exists
# error: shippingCost already exists
# error: shipping already exists
# error: shippingLevelsOfService already exists
# error: specialOrder already exists
# error: shortDescription already exists
# error: shortDescriptionHtml already exists
# error: class already exists
# error: classId already exists
# error: subclass already exists
# error: subclassId already exists
# error: department already exists
# error: departmentId already exists
# error: bestBuyItemId already exists
# error: protectionPlanTerm already exists
# error: protectionPlanType already exists
# error: protectionPlanLowPrice already exists
# error: protectionPlanHighPrice already exists
# error: buybackPlans already exists
# error: protectionPlans already exists
# error: protectionPlanDetails already exists
# error: productFamilies already exists
# error: productVariations already exists
# error: aspectRatio already exists
# error: screenFormat already exists
# error: lengthInMinutes already exists
# error: mpaaRating already exists
# error: plot already exists
# error: plotHtml already exists
# error: studio already exists
# error: theatricalReleaseDate already exists
# error: description already exists
# error: manufacturer already exists
# error: modelNumber already exists
# error: images already exists
# error: image already exists
# error: largeFrontImage already exists
# error: mediumImage already exists
# error: thumbnailImage already exists
# error: largeImage already exists
# error: alternateViewsImage already exists
# error: angleImage already exists
# error: backViewImage already exists
# error: energyGuideImage already exists
# error: leftViewImage already exists
# error: accessoriesImage already exists
# error: remoteControlImage already exists
# error: rightViewImage already exists
# error: topViewImage already exists
# error: albumTitle already exists
# error: artistName already exists
# error: artistId already exists
# error: originalReleaseDate already exists
# error: parentalAdvisory already exists
# error: mediaCount already exists
# error: monoStereo already exists
# error: studioLive already exists
# error: condition already exists
# error: inStorePickup already exists
# error: friendsAndFamilyPickup already exists
# error: homeDelivery already exists
# error: quantityLimit already exists
# error: fulfilledBy already exists
# error: members already exists
# error: bundledIn already exists
# error: albumLabel already exists
# error: genre already exists
# error: color already exists
# error: depth already exists
# error: dollarSavings already exists
# error: percentSavings already exists
# error: tradeInValue already exists
# error: height already exists
# error: orderable already exists
# error: weight already exists
# error: shippingWeight already exists
# error: width already exists
# error: warrantyLabor already exists
# error: warrantyParts already exists
# error: softwareAge already exists
# error: softwareGrade already exists
# error: platform already exists
# error: numberOfPlayers already exists
# error: softwareNumberOfPlayers already exists
# error: esrbRating already exists
# error: longDescription already exists
# error: longDescriptionHtml already exists
# error: cast already exists
# error: crew already exists
# error: details already exists
# error: includedItemList already exists
# error: features already exists
# error: offers already exists
# error: marketplace already exists
# error: listingId already exists
# error: sellerId already exists
# error: shippingRestrictions already exists
# error: discs already exists
# error: commerceSku already exists
# error: haulawayAvailable already exists
# error: proposition65WarningMessage already exists
# error: proposition65WarningType already exists
# error: productAspectRatio already exists
# error: headphoneJacks already exists
# error: energyStarQualified already exists
# pg=1 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEwMjAzNDhfdXM=' | t1=33945.1970943 | perf_counter()-t1=2.672516700004053
# pg=2 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEwMjk3ODVfdXM=' | t1=33945.1970943 | perf_counter()-t1=4.939380399999209
# pg=3 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEwNzMxMTlfdXM=' | t1=33945.1970943 | perf_counter()-t1=9.006615500002226
# pg=4 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEwODY5NzZfdXM=' | t1=33945.1970943 | perf_counter()-t1=11.47140500000387
# pg=5 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzExMTQxMjk0X3Vz' | t1=33960.9366505 | perf_counter()-t1=1.1900003300979733e-05
# pg=6 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzExNDQxOTdfdXM=' | t1=33960.9366505 | perf_counter()-t1=3.0835101999982726
# pg=7 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzExNzEwNzlfdXM=' | t1=33960.9366505 | perf_counter()-t1=5.841333800002758
# pg=8 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzExOTI3MDA3X3Vz' | t1=33960.9366505 | perf_counter()-t1=8.432859599997755
# pg=9 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEyMjQwMzJfdXM=' | t1=33960.9366505 | perf_counter()-t1=11.332434299998567
# pg=10 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEyNTgwMDFfdXM=' | t1=33975.0900979 | perf_counter()-t1=1.8600003386382014e-05
# pg=11 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzEyOTc1OTA3X3Vz' | t1=33975.0900979 | perf_counter()-t1=3.313767400002689
# pg=12 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEzMDg2MjVfdXM=' | t1=33975.0900979 | perf_counter()-t1=6.0542851999998675
# pg=13 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzEzMjAzMDE3X3Vz' | t1=33975.0900979 | perf_counter()-t1=8.703559200002928
# pg=14 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEzMjg5MjlfdXM=' | t1=33975.0900979 | perf_counter()-t1=11.122033999999985
# pg=15 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzEzMzY4Njg4X3Vz' | t1=33988.5075002 | perf_counter()-t1=1.2399999832268804e-05
# pg=16 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEzNDQ4NDRfdXM=' | t1=33988.5075002 | perf_counter()-t1=2.039243200000783
# pg=17 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzEzNTU3ODQ5X3Vz' | t1=33988.5075002 | perf_counter()-t1=4.0554868999970495
# pg=18 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzEzNjcwNjFfdXM=' | t1=33988.5075002 | perf_counter()-t1=6.7835788000011235
# pg=19 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzEzNzczMjc3X3Vz' | t1=33988.5075002 | perf_counter()-t1=9.112737299998116
# pg=20 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzEzODY3MTEyX3Vz' | t1=33999.8528242 | perf_counter()-t1=1.2099997547920793e-05
# pg=21 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzEzOTU5NjM4X3Vz' | t1=33999.8528242 | perf_counter()-t1=2.9671181999947294
# pg=22 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0MDI0MzYxX3Vz' | t1=33999.8528242 | perf_counter()-t1=5.512075399994501
# pg=23 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0MDgwMTg0X3Vz' | t1=33999.8528242 | perf_counter()-t1=7.65735180000047
# pg=24 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0MTgxNTgzX3Vz' | t1=33999.8528242 | perf_counter()-t1=10.008773699999438
# pg=25 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0MjUwOTQ1X3Vz' | t1=34012.0614465 | perf_counter()-t1=9.199997293762863e-06
# pg=26 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0MzA2NTU2X3Vz' | t1=34012.0614465 | perf_counter()-t1=2.0907392999943113
# pg=27 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0Mzg1NTMyX3Vz' | t1=34012.0614465 | perf_counter()-t1=4.241809799998009
# pg=28 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0NDk0NjAxX3Vz' | t1=34012.0614465 | perf_counter()-t1=6.614520699993591
# pg=29 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0NjAxMDA0X3Vz' | t1=34012.0614465 | perf_counter()-t1=9.071962599999097
# pg=30 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE0NzIwMDY0X3Vz' | t1=34023.0280975 | perf_counter()-t1=1.2399999832268804e-05
# pg=31 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE
| nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE3ODY5MDc3X3Vz' | t1=34153.4280647 | perf_counter()-t1=6.582805600002757
# pg=89 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE3ODkzMTkzX3Vz' | t1=34153.4280647 | perf_counter()-t1=19.451468899998872
# pg=90 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzE3OTQxMDJfdXM=' | t1=34175.5532204 | perf_counter()-t1=1.1399999493733048e-05
# pg=91 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE3OTc5MTE4X3Vz' | t1=34175.5532204 | perf_counter()-t1=2.2426144999990356
# pg=92 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MDIyMjM5X3Vz' | t1=34175.5532204 | perf_counter()-t1=4.350141499999154
# pg=93 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MDU3MDc3X3Vz' | t1=34175.5532204 | perf_counter()-t1=6.692420800005493
# pg=94 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MDk0NjQyX3Vz' | t1=34175.5532204 | perf_counter()-t1=9.017204800002219
# pg=95 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MTE1NTIxX3Vz' | t1=34186.9028904 | perf_counter()-t1=1.219999830937013e-05
# pg=96 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MTM2NTcxX3Vz' | t1=34186.9028904 | perf_counter()-t1=2.2500137999959406
# pg=97 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MTcwMjc1X3Vz' | t1=34186.9028904 | perf_counter()-t1=4.6152232000022195
# pg=98 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MjAwMDE5X3Vz' | t1=34186.9028904 | perf_counter()-t1=6.741409199996269
# pg=99 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MjI5MzAxX3Vz' | t1=34186.9028904 | perf_counter()-t1=9.041838899996947
# pg=100 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MjYxMjkzX3Vz' | t1=34197.9610984 | perf_counter()-t1=1.1299998732283711e-05
# pg=101 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MzA0MTE5X3Vz' | t1=34197.9610984 | perf_counter()-t1=2.1674904999963474
# pg=102 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MzI3NjMyX3Vz' | t1=34197.9610984 | perf_counter()-t1=4.376805699997931
# pg=103 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4MzU4NjEzX3Vz' | t1=34197.9610984 | perf_counter()-t1=6.4000901999970665
# pg=104 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4Mzk2Nzk0X3Vz' | t1=34197.9610984 | perf_counter()-t1=8.667041699998663
# pg=105 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NDI2MjYyX3Vz' | t1=34208.7029955 | perf_counter()-t1=1.1999996786471456e-05
# pg=106 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NDY0Mzc3X3Vz' | t1=34208.7029955 | perf_counter()-t1=2.0589652999988175
# pg=107 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NDkzODIzX3Vz' | t1=34208.7029955 | perf_counter()-t1=4.008267099998193
# pg=108 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzE4NTM2NjVfdXM=' | t1=34208.7029955 | perf_counter()-t1=5.973115999993752
# pg=109 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NTU5OTY1X3Vz' | t1=34208.7029955 | perf_counter()-t1=8.116861299997254
# pg=110 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NTgyODIzX3Vz' | t1=34219.1037142 | perf_counter()-t1=1.2100004823878407e-05
# pg=111 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NjI0NDAxX3Vz' | t1=34219.1037142 | perf_counter()-t1=1.9256354000026477
# pg=112 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NjYwOTMzX3Vz' | t1=34219.1037142 | perf_counter()-t1=3.9426163000025554
# pg=113 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4Njk3OTgxX3Vz' | t1=34219.1037142 | perf_counter()-t1=6.026744900002086
# pg=114 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NzE0NTE5X3Vz' | t1=34219.1037142 | perf_counter()-t1=8.399925600002462
# pg=115 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NzQ4MDY2X3Vz' | t1=34229.4964641 | perf_counter()-t1=1.4900004316587001e-05
# pg=116 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NzY3NjE3X3Vz' | t1=34229.4964641 | perf_counter()-t1=2.056836200004909
# pg=117 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4NzkxMTE5X3Vz' | t1=34229.4964641 | perf_counter()-t1=3.9817318999994313
# pg=118 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4ODE3ODk0X3Vz' | t1=34229.4964641 | perf_counter()-t1=5.9738692000028095
# pg=119 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4ODM4OTMzX3Vz' | t1=34229.4964641 | perf_counter()-t1=8.53119660000084
# pg=120 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4ODU5OTYyX3Vz' | t1=34240.1716739 | perf_counter()-t1=1.3900003978051245e-05
# pg=121 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzE4ODgwNjVfdXM=' | t1=34240.1716739 | perf_counter()-t1=2.0395964000053937
# pg=122 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4ODk4ODE1X3Vz' | t1=34240.1716739 | perf_counter()-t1=4.806570700005977
# pg=123 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTIzODg1X3Vz' | t1=34240.1716739 | perf_counter()-t1=6.984335400004056
# pg=124 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTUwNjk3X3Vz' | t1=34240.1716739 | perf_counter()-t1=8.933240300000762
# pg=125 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTUxODk2X3Vz' | t1=34251.2124377 | perf_counter()-t1=1.6999998479150236e-05
# pg=126 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTUzMzU4X3Vz' | t1=34251.2124377 | perf_counter()-t1=2.492221699998481
# pg=127 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTU1NTEzX3Vz' | t1=34251.2124377 | perf_counter()-t1=4.891165499997442
# pg=128 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTU3MTc4X3Vz' | t1=34251.2124377 | perf_counter()-t1=6.874194900003204
# pg=129 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTU4NDA0X3Vz' | t1=34251.2124377 | perf_counter()-t1=8.941053900001862
# pg=130 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTU5NjUyX3Vz' | t1=34262.0794773 | perf_counter()-t1=3.0099996365606785e-05
# pg=131 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE4OTc2NTM3X3Vz' | t1=34262.0794773 | perf_counter()-t1=2.191010800001095
# pg=132 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MDAxMzkxX3Vz' | t1=34262.0794773 | perf_counter()-t1=4.357633499996155
# pg=133 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MDI2ODgxX3Vz' | t1=34262.0794773 | perf_counter()-t1=6.499745199995232
# pg=134 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MDUwMjM1X3Vz' | t1=34262.0794773 | perf_counter()-t1=8.50697489999584
# pg=135 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MDg4MjA3X3Vz' | t1=34272.4294514 | perf_counter()-t1=1.1900003300979733e-05
# pg=136 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MTEwODk4X3Vz' | t1=34272.4294514 | perf_counter()-t1=2.1831643999976222
# pg=137 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MTMxMjIxX3Vz' | t1=34272.4294514 | perf_counter()-t1=4.549352300004102
# pg=138 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MTYzOTA4X3Vz' | t1=34272.4294514 | perf_counter()-t1=6.798814900001162
# pg=139 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MjAwNjU0X3Vz' | t1=34272.4294514 | perf_counter()-t1=9.048981599997205
# pg=140 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MjM2ODU5X3Vz' | t1=34283.4367967 | perf_counter()-t1=1.2399999832268804e-05
# pg=141 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MjU5MDEyX3Vz' | t1=34283.4367967 | perf_counter()-t1=2.0499748000002
# pg=142 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5Mjc3MDU3X3Vz' | t1=34283.4367967 | perf_counter()-t1=4.474291699996684
# pg=143 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5Mjk3NTQyX3Vz' | t1=34283.4367967 | perf_counter()-t1=7.024815199998557
# pg=144 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzE5MzEzNTRfdXM=' | t1=34283.4367967 | perf_counter()-t1=9.251470399998652
# pg=145 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MzM5MTc5X3Vz' | t1=34294.6879764 | perf_counter()-t1=1.2500000593718141e-05
# pg=146 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5MzY4NzkyX3Vz' | t1=34294.6879764 | perf_counter()-t1=2.232852400004049
# pg=147 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5Mzg2NzEyX3Vz' | t1=34294.6879764 | perf_counter()-t1=4.507797199999914
# pg=148 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5Mzk5OTY0X3Vz' | t1=34294.6879764 | perf_counter()-t1=6.6179111000019475
# pg=149 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NDMyMTU3X3Vz' | t1=34294.6879764 | perf_counter()-t1=8.645261600002414
# pg=150 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NDU1MTQ4X3Vz' | t1=34305.6783826 | perf_counter()-t1=1.2500000593718141e-05
# pg=151 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NDc5MzE4X3Vz' | t1=34305.6783826 | perf_counter()-t1=1.9911619999984396
# pg=152 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NTA2OTU1X3Vz' | t1=34305.6783826 | perf_counter()-t1=4.041410999998334
# pg=153 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NTIxMjY2X3Vz' | t1=34305.6783826 | perf_counter()-t1=6.125807599994005
# pg=154 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NTM2MDM3X3Vz' | t1=34305.6783826 | perf_counter()-t1=8.101215700000466
# pg=155 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NTY4MDQ0X3Vz' | t1=34316.2371965 | perf_counter()-t1=1.3199998647905886e-05
# pg=156 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NTkyMDg2X3Vz' | t1=34316.2371965 | perf_counter()-t1=2.2494357000032323
# pg=157 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NjM4ODE3X3Vz' | t1=34316.2371965 | perf_counter()-t1=4.191665700003796
# pg=158 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NjQxODkyX3Vz' | t1=34316.2371965 | perf_counter()-t1=6.409024900000077
# pg=159 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NjU4MTg5X3Vz' | t1=34316.2371965 | perf_counter()-t1=8.399783100001514
# pg=160 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NjgxMDMxX3Vz' | t1=34326.8953648 | perf_counter()-t1=1.2500000593718141e-05
# pg=161 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NzA5MjQ0X3Vz' | t1=34326.8953648 | perf_counter()-t1=2.208590499998536
# pg=161 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NzA5MjQ0X3Vz' | t1=34326.8953648 | perf_counter()-t1=32.67109530000016
# pg=162 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5NzU3NjAxX3Vz' | t1=34326.8953648 | perf_counter()-t1=34.673924999995506
# pg=163 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5Nzc2MjkzX3Vz' | t1=34326.8953648 | perf_counter()-t1=36.99176129999978
# pg=164 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzE5ODA1NzZfdXM=' | t1=34326.8953648 | perf_counter()-t1=39.52541789999668
# pg=165 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5ODI4NzM2X3Vz' | t1=34368.8461096 | perf_counter()-t1=8.999995770864189e-06
# pg=166 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5ODU0Mjc5X3Vz' | t1=34368.8461096 | perf_counter()-t1=2.336609899997711
# pg=167 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5ODgyNjg0X3Vz' | t1=34368.8461096 | perf_counter()-t1=4.4133864999967045
# pg=168 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5OTAxNDI1X3Vz' | t1=34368.8461096 | perf_counter()-t1=6.7240520999985165
# pg=169 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5OTE5NTc2X3Vz' | t1=34368.8461096 | perf_counter()-t1=9.124140499996429
# pg=170 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5OTI4NDIyX3Vz' | t1=34380.4263983 | perf_counter()-t1=1.1800002539530396e-05
# pg=171 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5OTQyNTI4X3Vz' | t1=34380.4263983 | perf_counter()-t1=2.085260300002119
# pg=172 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzE5OTY2NzYxX3Vz' | t1=34380.4263983 | perf_counter()-t1=4.13567100000364
# pg=173 | nextcursorMark='AoIIP4AAADNwcm9kdWN0X
| nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNTE5NTAyX3Vz' | t1=34516.7040728 | perf_counter()-t1=6.419122799998149
# pg=233 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNTM5NzAzX3Vz' | t1=34516.7040728 | perf_counter()-t1=8.638155699998606
# pg=234 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNTU4MTg1X3Vz' | t1=34516.7040728 | perf_counter()-t1=10.901074699999299
# pg=235 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNTcyMDM2X3Vz' | t1=34530.0058038 | perf_counter()-t1=1.309999788645655e-05
# pg=236 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNTg1NTczX3Vz' | t1=34530.0058038 | perf_counter()-t1=2.506970000002184
# pg=237 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNjAxMjc1X3Vz' | t1=34530.0058038 | perf_counter()-t1=4.657073200003651
# pg=238 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNjIwMjYxX3Vz' | t1=34530.0058038 | perf_counter()-t1=6.7254094000018085
# pg=239 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNjM2NzMyX3Vz' | t1=34530.0058038 | perf_counter()-t1=9.014673099998618
# pg=240 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNjU5MTY1X3Vz' | t1=34541.345916 | perf_counter()-t1=1.1900003300979733e-05
# pg=241 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNjc3NzA0X3Vz' | t1=34541.345916 | perf_counter()-t1=2.3007075999994413
# pg=242 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNjk4NzAzX3Vz' | t1=34541.345916 | perf_counter()-t1=4.5010923000008916
# pg=243 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNzE5MTU4X3Vz' | t1=34541.345916 | perf_counter()-t1=6.761347100000421
# pg=243 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNzE5MTU4X3Vz' | t1=34541.345916 | perf_counter()-t1=7.1679119000036735
# pg=243 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNzE5MTU4X3Vz' | t1=34541.345916 | perf_counter()-t1=7.593682600003376
# pg=243 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNzE5MTU4X3Vz' | t1=34541.345916 | perf_counter()-t1=8.01409920000151
# pg=243 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNzE5MTU4X3Vz' | t1=34541.345916 | perf_counter()-t1=8.44949710000219
# pg=244 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNzM4MTk5X3Vz' | t1=34541.345916 | perf_counter()-t1=10.65130190000491
# pg=245 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxNzU0NzE4X3Vz' | t1=34554.1589086 | perf_counter()-t1=2.7900001441594213e-05
# pg=246 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxODE4MTgyX3Vz' | t1=34554.1589086 | perf_counter()-t1=2.027264299998933
# pg=247 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxODUyODc5X3Vz' | t1=34554.1589086 | perf_counter()-t1=4.7614119999998366
# pg=248 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxODcxNTYxX3Vz' | t1=34554.1589086 | perf_counter()-t1=6.894263399997726
# pg=249 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxODk3MjY2X3Vz' | t1=34554.1589086 | perf_counter()-t1=9.328614999998535
# pg=250 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxOTM5MzgyX3Vz' | t1=34565.428403 | perf_counter()-t1=1.1299998732283711e-05
# pg=251 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIxOTc4OTgxX3Vz' | t1=34565.428403 | perf_counter()-t1=1.8419653000019025
# pg=252 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMDA2MDMxX3Vz' | t1=34565.428403 | perf_counter()-t1=4.035708700001123
# pg=253 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMDA4MDY2X3Vz' | t1=34565.428403 | perf_counter()-t1=6.211315400003514
# pg=254 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMDEyNzk2X3Vz' | t1=34565.428403 | perf_counter()-t1=8.751090900004783
# pg=255 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMDE0MTYyX3Vz' | t1=34576.406082 | perf_counter()-t1=1.0700001439545304e-05
# pg=256 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMDIwNTIxX3Vz' | t1=34576.406082 | perf_counter()-t1=2.023392099996272
# pg=257 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMDQyNzkzX3Vz' | t1=34576.406082 | perf_counter()-t1=4.532105799997225
# pg=258 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMDgwNDA0X3Vz' | t1=34576.406082 | perf_counter()-t1=6.698151500000677
# pg=259 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMTIxODI5X3Vz' | t1=34576.406082 | perf_counter()-t1=8.914883099998406
# pg=260 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMTMyNTc4X3Vz' | t1=34587.5131153 | perf_counter()-t1=1.1800002539530396e-05
# pg=261 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMTQ2Mzg1X3Vz' | t1=34587.5131153 | perf_counter()-t1=1.8896826000054716
# pg=262 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMTY5NzExX3Vz' | t1=34587.5131153 | perf_counter()-t1=4.334239600000728
# pg=263 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMjQwMTk4X3Vz' | t1=34587.5131153 | perf_counter()-t1=6.400159500000882
# pg=264 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMjY5MTc5X3Vz' | t1=34587.5131153 | perf_counter()-t1=8.349395400000503
# pg=265 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMjkzNzA3X3Vz' | t1=34598.1127622 | perf_counter()-t1=1.6600002709310502e-05
# pg=266 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMzA2OTc1X3Vz' | t1=34598.1127622 | perf_counter()-t1=2.00742220000393
# pg=267 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMzM2ODcyX3Vz' | t1=34598.1127622 | perf_counter()-t1=4.524332100001629
# pg=268 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyMzcxNzE3X3Vz' | t1=34598.1127622 | perf_counter()-t1=6.700474299999769
# pg=269 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyNDExOTAyX3Vz' | t1=34598.1127622 | perf_counter()-t1=9.100433899999189
# pg=270 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzIyNDYyNTJfdXM=' | t1=34609.4872171 | perf_counter()-t1=1.1999996786471456e-05
# pg=271 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyNTA3NjI3X3Vz' | t1=34609.4872171 | perf_counter()-t1=2.1561337999955867
# pg=272 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzIyNTI4NjRfdXM=' | t1=34609.4872171 | perf_counter()-t1=4.425699299994449
# pg=273 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyNTcxMTU2X3Vz' | t1=34609.4872171 | perf_counter()-t1=6.642064299994672
# pg=274 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyNjI2ODkyX3Vz' | t1=34609.4872171 | perf_counter()-t1=8.624865199999476
# pg=275 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyNjk1MzQzX3Vz' | t1=34619.8717862 | perf_counter()-t1=1.2100004823878407e-05
# pg=276 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyNzcwMTQ2X3Vz' | t1=34619.8717862 | perf_counter()-t1=2.1499276000031387
# pg=277 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyNzkwNTA1X3Vz' | t1=34619.8717862 | perf_counter()-t1=4.784321300001466
# pg=278 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyODA0MjE5X3Vz' | t1=34619.8717862 | perf_counter()-t1=7.06606230000034
# pg=279 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyODE2MDExX3Vz' | t1=34619.8717862 | perf_counter()-t1=9.157669000000169
# pg=280 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyODYwNTIyX3Vz' | t1=34631.079396 | perf_counter()-t1=1.1399999493733048e-05
# pg=281 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIyOTUxNTExX3Vz' | t1=34631.079396 | perf_counter()-t1=2.1246885000000475
# pg=282 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzIzMDEyMjJfdXM=' | t1=34631.079396 | perf_counter()-t1=4.424350499997672
# pg=283 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzMDU2NDEyX3Vz' | t1=34631.079396 | perf_counter()-t1=6.624184599997534
# pg=284 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzMDgxODk3X3Vz' | t1=34631.079396 | perf_counter()-t1=8.750862699998834
# pg=285 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzMjkyNzEyX3Vz' | t1=34641.6793248 | perf_counter()-t1=1.8399994587525725e-05
# pg=286 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzMzA3MTgzX3Vz' | t1=34641.6793248 | perf_counter()-t1=1.9245931999976165
# pg=287 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzMzM4MTA3X3Vz' | t1=34641.6793248 | perf_counter()-t1=4.1671094999983325
# pg=288 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzMzYyMzYyX3Vz' | t1=34641.6793248 | perf_counter()-t1=6.400974299998779
# pg=289 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzNDAxNDg1X3Vz' | t1=34641.6793248 | perf_counter()-t1=8.601016699998581
# pg=290 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzNDYxODQ4X3Vz' | t1=34652.2797115 | perf_counter()-t1=1.1299998732283711e-05
# pg=291 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzNDg3MjM0X3Vz' | t1=34652.2797115 | perf_counter()-t1=1.9999998999992386
# pg=292 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzNTA0OTg5X3Vz' | t1=34652.2797115 | perf_counter()-t1=3.7990434000021196
# pg=293 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzIzODI0NDQ0X3Vz' | t1=34652.2797115 | perf_counter()-t1=5.804895599998417
# pg=294 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MDE2NDY4X3Vz' | t1=34652.2797115 | perf_counter()-t1=7.874912300001597
# pg=295 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MDY1MDI1X3Vz' | t1=34662.6206824 | perf_counter()-t1=1.8500002624932677e-05
# pg=296 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MDk5NDI0X3Vz' | t1=34662.6206824 | perf_counter()-t1=2.2076648000002024
# pg=297 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MTMyOTA2X3Vz' | t1=34662.6206824 | perf_counter()-t1=4.376573100002133
# pg=298 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MTU5NDg3X3Vz' | t1=34662.6206824 | perf_counter()-t1=6.29228200000216
# pg=299 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MTgxMzYxX3Vz' | t1=34662.6206824 | perf_counter()-t1=8.217911300002015
# pg=300 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MjExMjA2X3Vz' | t1=34672.9414976 | perf_counter()-t1=1.2300006346777081e-05
# pg=301 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MjI3MTM3X3Vz' | t1=34672.9414976 | perf_counter()-t1=2.279935000005935
# pg=302 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MjUzMjYzX3Vz' | t1=34672.9414976 | perf_counter()-t1=4.504403800005093
# pg=303 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0MjkzOTM1X3Vz' | t1=34672.9414976 | perf_counter()-t1=6.554105000002892
# pg=304 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzI0MzMwOTNfdXM=' | t1=34672.9414976 | perf_counter()-t1=8.612480499999947
# pg=305 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0NjU3MzUxX3Vz' | t1=34683.8593583 | perf_counter()-t1=1.4200006262399256e-05
# pg=306 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0Njc2NjgzX3Vz' | t1=34683.8593583 | perf_counter()-t1=2.154130000002624
# pg=307 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0NzUwMTgzX3Vz' | t1=34683.8593583 | perf_counter()-t1=4.545250900002429
# pg=308 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0Nzg0NTY2X3Vz' | t1=34683.8593583 | perf_counter()-t1=6.7199743000019225
# pg=309 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0ODAxNjc2X3Vz' | t1=34683.8593583 | perf_counter()-t1=8.704736900006537
# pg=310 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0ODI3MjY0X3Vz' | t1=34694.6877047 | perf_counter()-t1=1.1500000255182385e-05
# pg=311 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0ODQ5OTM1X3Vz' | t1=34694.6877047 | perf_counter()-t1=2.260038299995358
# pg=312 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0ODcyMjIyX3Vz' | t1=34694.6877047 | perf_counter()-t1=4.367254799995862
# pg=313 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0OTA0NzcyX3Vz' | t1=34694.6877047 | perf_counter()-t1=6.5586937999978545
# pg=314 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0OTI3MTQ5X3Vz' | t1=34694.6877047 | perf_counter()-t1=8.700793500000145
# pg=315 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI0OTg2NDQ2X3Vz' | t1=34705.5627447 | perf_counter()-t1=1.2500000593718141e-05
# pg=316 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MDA0MDQxX3Vz' | t1=34705.5627447 | perf_counter()-t1=2.09995109999727
# pg=317 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MDI4MzE5X3Vz' | t1=34705.5627447 | perf_counter()-t1=4.174837200000184
# pg=318 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MDY2MTkxX3Vz' | t1=34705.5627447 | perf_counter()-t1=6.30043029999797
# pg=319 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MDkyNzE4X3Vz' | t1=34705.5627447 | perf_counter()-t1=8.260283099996741
# pg=320 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MTEzOTAyX3Vz' | t1=34716.2218644 | perf_counter()-t1=1.4899997040629387e-05
# pg=321 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MTQwNzkzX3Vz' | t1=34716.2218644 | perf_counter()-t1=1.899497300000803
# pg=322 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MTc0MjE2X3Vz' | t1=34716.2218644 | perf_counter()-t1=4.183377199995448
# pg=323 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MTkzMzIxX3Vz' | t1=34716.2218644 | perf_counter()-t1=6.24917579999601
# pg=324 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MjA2ODM5X3Vz' | t1=34716.2218644 | perf_counter()-t1=8.449411599998712
# pg=325 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MjMyMjY4X3Vz' | t1=34726.9044371 | perf_counter()-t1=1.5900004655122757e-05
# pg=326 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1Mjc0MTQ2X3Vz' | t1=34726.9044371 | perf_counter()-t1=2.316614200004551
# pg=327 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MjkyMjA4X3Vz' | t1=34726.9044371 | perf_counter()-t1=4.441572100004123
# pg=328 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MzMzMTUxX3Vz' | t1=34726.9044371 | perf_counter()-t1=6.875871600001119
# pg=329 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MzU2MTI1X3Vz' | t1=34726.9044371 | perf_counter()-t1=9.0938141000006
# pg=330 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1MzczODMyX3Vz' | t1=34738.4640403 | perf_counter()-t1=1.189999602502212e-05
# pg=331 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1Mzk3MTg4X3Vz' | t1=34738.4640403 | perf_counter()-t1=2.317169299996749
# pg=332 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1NDIxNTQzX3Vz' | t1=34738.4640403 | perf_counter()-t1=4.607615799999621
# pg=333 | nextcursorMark='AoIIP4AAADNwcm9kdWN0XzI1NDMxNDU5X3Vz' | t1=34738.4640403 | perf_counter()-t1=6.75737929999741
# ...
# pg=2123 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY0OTA2MzJfdXM=' | t1=38904.7728495 | perf_counter()-t1=6.859396700005163
# pg=2124 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY0OTA3NDhfdXM=' | t1=38904.7728495 | perf_counter()-t1=9.47640720000345
# pg=2125 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY1NTQzMDdfdXM=' | t1=38916.6136358 | perf_counter()-t1=1.3999997463542968e-05
# pg=2126 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY2Mjc3OTZfdXM=' | t1=38916.6136358 | perf_counter()-t1=2.3285458000027575
# pg=2127 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY2NzMyODFfdXM=' | t1=38916.6136358 | perf_counter()-t1=4.468756599999324
# pg=2128 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY2OTc5MzdfdXM=' | t1=38916.6136358 | perf_counter()-t1=6.626941100003023
# pg=2129 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY3MzUyMzJfdXM=' | t1=38916.6136358 | perf_counter()-t1=8.767305299996224
# pg=2130 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY3NjkyMjhfdXM=' | t1=38927.5900944 | perf_counter()-t1=1.720000000204891e-05
# pg=2131 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY4MDg0NDRfdXM=' | t1=38927.5900944 | perf_counter()-t1=2.1001420999964466
# pg=2132 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY4NDIxMzdfdXM=' | t1=38927.5900944 | perf_counter()-t1=4.282937099997071
# pg=2133 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY4ODAxNDZfdXM=' | t1=38927.5900944 | perf_counter()-t1=7.866156999996747
# pg=2134 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY5MDcxNDhfdXM=' | t1=38927.5900944 | perf_counter()-t1=10.534050999995088
# pg=2135 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY5MTY1MTZfdXM=' | t1=38940.3154481 | perf_counter()-t1=1.219999830937013e-05
# pg=2136 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY5MzQwODFfdXM=' | t1=38940.3154481 | perf_counter()-t1=1.923797999996168
# pg=2137 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY5NTg5MDlfdXM=' | t1=38940.3154481 | perf_counter()-t1=4.334404499997618
# pg=2138 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY5Nzc0MzVfdXM=' | t1=38940.3154481 | perf_counter()-t1=6.491696199998842
# pg=2139 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzY5OTgzNzlfdXM=' | t1=38940.3154481 | perf_counter()-t1=8.709033899998758
# pg=2140 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzcwNDUxNjRfdXM=' | t1=38951.4400178 | perf_counter()-t1=1.1399999493733048e-05
# pg=2141 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzcwNzQzMjhfdXM=' | t1=38951.4400178 | perf_counter()-t1=2.424778699998569
# pg=2142 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzcxMzYwODNfdXM=' | t1=38951.4400178 | perf_counter()-t1=4.60019900000043
# pg=2143 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzcxNTY0NzJfdXM=' | t1=38951.4400178 | perf_counter()-t1=6.885164999999688
# pg=2144 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzcxODY0NjdfdXM=' | t1=38951.4400178 | perf_counter()-t1=8.96838640000351
# pg=2145 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzcyMTc2NzRfdXM=' | t1=38962.5253501 | perf_counter()-t1=1.4200006262399256e-05
# pg=2146 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzcyNjMwMjVfdXM=' | t1=38962.5253501 | perf_counter()-t1=2.266886200006411
# pg=2147 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzczMDcxMTJfdXM=' | t1=38962.5253501 | perf_counter()-t1=4.428672500005632
# pg=2148 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzczMzgzMTFfdXM=' | t1=38962.5253501 | perf_counter()-t1=6.700219600003038
# pg=2149 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzczOTI5MTFfdXM=' | t1=38962.5253501 | perf_counter()-t1=9.117514800003846
# pg=2150 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc0NDYwMTZfdXM=' | t1=38973.9320495 | perf_counter()-t1=1.200000406242907e-05
# pg=2151 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc0ODI4NjlfdXM=' | t1=38973.9320495 | perf_counter()-t1=2.2168668000012985
# pg=2152 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc1NDAxMjhfdXM=' | t1=38973.9320495 | perf_counter()-t1=4.7840308000013465
# pg=2153 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc1ODQzMDNfdXM=' | t1=38973.9320495 | perf_counter()-t1=7.00152650000382
# pg=2154 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc2MTQxMTJfdXM=' | t1=38973.9320495 | perf_counter()-t1=9.150039100000868
# pg=2155 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc2NDk3NDZfdXM=' | t1=38985.2409336 | perf_counter()-t1=1.219999830937013e-05
# pg=2156 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc2OTEzMzlfdXM=' | t1=38985.2409336 | perf_counter()-t1=2.125447400001576
# pg=2157 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc2OTUxODlfdXM=' | t1=38985.2409336 | perf_counter()-t1=4.599425699998392
# pg=2158 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc3MjMwNDlfdXM=' | t1=38985.2409336 | perf_counter()-t1=6.908696700003929
# pg=2159 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc3NjQxMjVfdXM=' | t1=38985.2409336 | perf_counter()-t1=9.142389500004356
# pg=2160 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc4MDg2NDJfdXM=' | t1=38996.8330015 | perf_counter()-t1=1.5199999324977398e-05
# pg=2161 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc4Mzg1ODRfdXM=' | t1=38996.8330015 | perf_counter()-t1=2.1748986999955378
# pg=2162 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc4NjgxMTNfdXM=' | t1=38996.8330015 | perf_counter()-t1=4.197643199993763
# pg=2163 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc4ODgzNjdfdXM=' | t1=38996.8330015 | perf_counter()-t1=6.206754799997725
# pg=2164 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc5MTM0MDNfdXM=' | t1=38996.8330015 | perf_counter()-t1=8.558189099996525
# pg=2165 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzc5NjM5NTZfdXM=' | t1=39007.3817901 | perf_counter()-t1=1.4999997802078724e-05
# pg=2166 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgwMDI2NTNfdXM=' | t1=39007.3817901 | perf_counter()-t1=2.1339064999992843
# pg=2167 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgwMzgyNDFfdXM=' | t1=39007.3817901 | perf_counter()-t1=4.283755999997084
# pg=2168 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgxMDMxOThfdXM=' | t1=39007.3817901 | perf_counter()-t1=6.534887900001195
# pg=2169 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgxMzYwMzdfdXM=' | t1=39007.3817901 | perf_counter()-t1=8.650183099998685
# pg=2170 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgxNzU0NjhfdXM=' | t1=39018.1580319 | perf_counter()-t1=1.2299999070819467e-05
# pg=2171 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgyMDY5NzlfdXM=' | t1=39018.1580319 | perf_counter()-t1=2.1584118000027956
# pg=2172 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgyMzU5MjlfdXM=' | t1=39018.1580319 | perf_counter()-t1=4.34089959999983
# pg=2173 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgyNTc2MTlfdXM=' | t1=39018.1580319 | perf_counter()-t1=6.465753500000574
# pg=2174 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgyOTA1NTZfdXM=' | t1=39018.1580319 | perf_counter()-t1=8.848890300003404
# pg=2175 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgzMTUyODFfdXM=' | t1=39029.1231131 | perf_counter()-t1=1.189999602502212e-05
# pg=2176 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgzNDQ1MTZfdXM=' | t1=39029.1231131 | perf_counter()-t1=2.1669479999982286
# pg=2177 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzgzNzE4OThfdXM=' | t1=39029.1231131 | perf_counter()-t1=4.712717599999451
# pg=2178 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg0MDcwOTFfdXM=' | t1=39029.1231131 | perf_counter()-t1=6.717929399994318
# pg=2179 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg0MzcwMjVfdXM=' | t1=39029.1231131 | perf_counter()-t1=8.976692899996124
# pg=2180 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg0NjI4ODlfdXM=' | t1=39040.2369104 | perf_counter()-t1=1.219999830937013e-05
# pg=2181 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg0OTEzMDNfdXM=' | t1=39040.2369104 | perf_counter()-t1=2.1630695999992895
# pg=2182 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg1MTgyNjhfdXM=' | t1=39040.2369104 | perf_counter()-t1=4.503050899998925
# pg=2183 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg1NDUwNzFfdXM=' | t1=39040.2369104 | perf_counter()-t1=6.711664799993741
# pg=2184 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg1ODg5ODZfdXM=' | t1=39040.2369104 | perf_counter()-t1=8.934954099997412
# pg=2185 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg2MjUwMTFfdXM=' | t1=39051.3992832 | perf_counter()-t1=1.4199998986441642e-05
# pg=2186 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg2NDgwMzdfdXM=' | t1=39051.3992832 | perf_counter()-t1=2.3497217999974964
# pg=2187 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg2ODA1MzZfdXM=' | t1=39051.3992832 | perf_counter()-t1=4.586250699998345
# pg=2188 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg3MTIwMzVfdXM=' | t1=39051.3992832 | perf_counter()-t1=7.005256199998257
# pg=2189 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg3MzUwMTVfdXM=' | t1=39051.3992832 | perf_counter()-t1=9.059215200002654
# pg=2190 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg3Njc5NTJfdXM=' | t1=39062.6083447 | perf_counter()-t1=1.2700002116616815e-05
# pg=2191 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg3OTAyNTRfdXM=' | t1=39062.6083447 | perf_counter()-t1=2.866061400003673
# pg=2192 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg4MTE4NDFfdXM=' | t1=39062.6083447 | perf_counter()-t1=4.982900499999232
# pg=2193 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg4MjkxMTlfdXM=' | t1=39062.6083447 | perf_counter()-t1=7.45956440000009
# pg=2194 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg4NTYzMzlfdXM=' | t1=39062.6083447 | perf_counter()-t1=10.065137500001583
# pg=2195 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg4NzM2MDJfdXM=' | t1=39074.8999912 | perf_counter()-t1=1.3299999409355223e-05
# pg=2196 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg4OTYwMTdfdXM=' | t1=39074.8999912 | perf_counter()-t1=2.2738255000003846
# pg=2197 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg5MTU4NjRfdXM=' | t1=39074.8999912 | perf_counter()-t1=4.6235928000023705
# pg=2198 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg5MzI5NzVfdXM=' | t1=39074.8999912 | perf_counter()-t1=6.583412499996484
# pg=2199 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg5NDE4MjNfdXM=' | t1=39074.8999912 | perf_counter()-t1=8.934333299999707
# pg=2200 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg5NDg4MDhfdXM=' | t1=39086.0681296 | perf_counter()-t1=1.410000550094992e-05
# pg=2201 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg5NTM1NTRfdXM=' | t1=39086.0681296 | perf_counter()-t1=2.0980900000067777
# pg=2202 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg5NjE3MTRfdXM=' | t1=39086.0681296 | perf_counter()-t1=4.155026000000362
# pg=2203 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg5NjQ0MThfdXM=' | t1=39086.0681296 | perf_counter()-t1=5.95561920000182
# pg=2204 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzg5OTQ2MDhfdXM=' | t1=39086.0681296 | perf_counter()-t1=8.747200600002543
# pg=2205 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkwMjEyNTdfdXM=' | t1=39097.0321432 | perf_counter()-t1=1.1500000255182385e-05
# pg=2206 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkwMzA4MDhfdXM=' | t1=39097.0321432 | perf_counter()-t1=2.162398899999971
# pg=2207 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkwNTgxODJfdXM=' | t1=39097.0321432 | perf_counter()-t1=4.44413060000079
# pg=2208 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkwNzkwODlfdXM=' | t1=39097.0321432 | perf_counter()-t1=7.48359590000473
# pg=2209 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkxMTA3MDNfdXM=' | t1=39097.0321432 | perf_counter()-t1=9.600185499999498
# pg=2210 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkxMzI2MjdfdXM=' | t1=39108.749007 | perf_counter()-t1=1.2700002116616815e-05
# pg=2211 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkxNTIyNDlfdXM=' | t1=39108.749007 | perf_counter()-t1=2.400673399999505
# pg=2212 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkxNzAyODNfdXM=' | t1=39108.749007 | perf_counter()-t1=4.516191800001252
# pg=2213 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkxOTI1NzFfdXM=' | t1=39108.749007 | perf_counter()-t1=6.70489169999928
# pg=2214 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkyMTQxODNfdXM=' | t1=39108.749007 | perf_counter()-t1=9.058509599999525
# pg=2215 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkyMzgyNDdfdXM=' | t1=39119.9457141 | perf_counter()-t1=1.8499995348975062e-05
# pg=2216 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkyNjUyMzRfdXM=' | t1=39119.9457141 | perf_counter()-t1=2.2611550000001444
# pg=2217 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkyOTM4MjhfdXM=' | t1=39119.9457141 | perf_counter()-t1=4.344553899994935
# pg=2218 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkzMjEwNjVfdXM=' | t1=39119.9457141 | perf_counter()-t1=6.511445799995272
# pg=2219 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkzNTcwMTFfdXM=' | t1=39119.9457141 | perf_counter()-t1=8.594993599996087
# pg=2220 | nextcursorMark='AoIIP4AAADJwcm9kdWN0XzkzODQ0MjdfdXM=' | t1=39130.5164499 | perf_counter()-t1=1.2299999070819467e-05
# pg=2221 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk0MTc4NTZfdXM=' | t1=39130.5164499 | perf_counter()-t1=2.333368200001132
# pg=2222 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk0MzM5NDVfdXM=' | t1=39130.5164499 | perf_counter()-t1=4.399473400000716
# pg=2223 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk0Mzc1NDlfdXM=' | t1=39130.5164499 | perf_counter()-t1=6.424026599997887
# pg=2224 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk0NTcwMzZfdXM=' | t1=39130.5164499 | perf_counter()-t1=8.474535499997728
# pg=2225 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk0ODExNDlfdXM=' | t1=39141.2979873 | perf_counter()-t1=1.3299999409355223e-05
# pg=2226 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk1MDMzMjVfdXM=' | t1=39141.2979873 | perf_counter()-t1=2.300360399996862
# pg=2227 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk1MTgyOTNfdXM=' | t1=39141.2979873 | perf_counter()-t1=4.384057199997187
# pg=2228 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk1NDI4MjdfdXM=' | t1=39141.2979873 | perf_counter()-t1=6.660872399996151
# pg=2229 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk1ODgwODNfdXM=' | t1=39141.2979873 | perf_counter()-t1=8.772134699996968
# pg=2230 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk2MTI1OTVfdXM=' | t1=39152.3759431 | perf_counter()-t1=1.6500001947861165e-05
# pg=2231 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk2NDA4OTRfdXM=' | t1=39152.3759431 | perf_counter()-t1=2.274087199999485
# pg=2232 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk2NzA3MDdfdXM=' | t1=39152.3759431 | perf_counter()-t1=4.273173499997938
# pg=2233 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk2OTQ1NzlfdXM=' | t1=39152.3759431 | perf_counter()-t1=6.39793009999994
# pg=2234 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk3MTg2MTNfdXM=' | t1=39152.3759431 | perf_counter()-t1=8.465625999997428
# pg=2235 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk3NDcwODZfdXM=' | t1=39163.2401589 | perf_counter()-t1=1.4199998986441642e-05
# pg=2236 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk3NzQyMjNfdXM=' | t1=39163.2401589 | perf_counter()-t1=2.294771699998819
# pg=2237 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk3OTY2NDZfdXM=' | t1=39163.2401589 | perf_counter()-t1=4.892473200001405
# pg=2238 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk4Mzk0NTdfdXM=' | t1=39163.2401589 | perf_counter()-t1=7.075811700000486
# pg=2239 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk4Nzc4MTdfdXM=' | t1=39163.2401589 | perf_counter()-t1=9.194325299999036
# pg=2240 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5MTg0NDRfdXM=' | t1=39174.6159208 | perf_counter()-t1=1.1299998732283711e-05
# pg=2241 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5NDY5MTNfdXM=' | t1=39174.6159208 | perf_counter()-t1=1.9913472999978694
# pg=2242 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5NjUxNDFfdXM=' | t1=39174.6159208 | perf_counter()-t1=4.057996999996249
# pg=2243 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5NjcyOTFfdXM=' | t1=39174.6159208 | perf_counter()-t1=5.840974399994593
# pg=2244 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5Njk5MTRfdXM=' | t1=39174.6159208 | perf_counter()-t1=7.615960899995116
# pg=2245 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5NzI3MzlfdXM=' | t1=39184.1481461 | perf_counter()-t1=1.2099997547920793e-05
# pg=2246 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5NzUzODFfdXM=' | t1=39184.1481461 | perf_counter()-t1=1.933264599996619
# pg=2247 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5ODUxODdfdXM=' | t1=39184.1481461 | perf_counter()-t1=3.9425651999990805
# pg=2248 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5ODgzOTdfdXM=' | t1=39184.1481461 | perf_counter()-t1=5.915860100001737
# pg=2249 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5OTE5NzZfdXM=' | t1=39184.1481461 | perf_counter()-t1=7.985289700001886
# pg=2250 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5OTY5MjZfdXM=' | t1=39194.1417065 | perf_counter()-t1=1.1900003300979733e-05
# pg=2251 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5OTg4MjRfdXM=' | t1=39194.1417065 | perf_counter()-t1=2.117085500001849
# pg=2252 | nextcursorMark='AoIIP4AAADJwcm9kdWN0Xzk5OTk0MDFfdXM=' | t1=39194.1417065 | perf_counter()-t1=3.421071700002358
# fin: (perf_counter()-t0)=5255.381938699997

# %% [markdown]
# Tip: To query for updates or deltas since you last walked through the result set you can use the itemUpdateDate attribute. To ensure that your query results include changes to a product’s active/inactive status, add active=* to your query parameters.
# For example: .../v1/products(itemUpdateDate>2017-02-06T16:00:00&active=*)?format=json&pageSize=100&cursorMark=*&apiKey=YOUR_API_KEY
# For example: .../v1/products(itemUpdateDate>today&active=*)?format=json&pageSize=100&cursorMark=*&apiKey=YOUR_API_KEY
# "https://api.bestbuy.com/v1/products(releaseDate>today)?format=json&show=sku,name,salePrice&apiKey=YourAPIKey"

# %%
bb_root = config_bestbuy.path
bb_dir = 'best_buy_20211123'
bb_path = os.path.join(bb_root, bb_dir)

bb_filename = 'best_buy_20211123_00001 - Copy.json'
bb_file_path = os.path.join(f'{bb_path}\\products', bb_filename)

with open(bb_file_path, 'r') as f:
    io = json.load(f)
# Out:
# C:\Users\Admin\Downloads\best_buy\best_buy_20211123

# %%
nextcursorMark = "*"
api_index = 3
page_size = 100
days = 2

r = api_bestbuy(cursorMark=nextcursorMark, api_index=api_index, page_size=page_size, days=days)
io = r.json()

# %%
db = os.path.join(config_bestbuy.path, 'bestbuy.db')
conn_string = f'sqlite:///{db}'
engine = create_engine(conn_string)

with engine.connect() as cnx:
    # df.to_sql(name='products', con=cnx, if_exists='replace', index=False)
    
    rs = cnx.execute("select max(itemUpdateDate) from products")
    for row in rs:
        print(row)
# Out:
# ('2021-11-26T03:43:37',)

# %%
today = datetime.utcnow().date()
n_days = datetime.utcnow().date() - timedelta(days=2)
n_hours = (today-n_days)/timedelta(seconds=1)
n_hours
# Out:
# 172800.0

# %%
['nextCursorMark', 'total', 'totalPages', 'queryTime', 'totalTime', 'canonicalUrl', 'sku', 'name', 'type', 'startDate', 'new', 'activeUpdateDate', 'active', 'regularPrice', 'salePrice', 'clearance', 'onSale', 'categoryPath', 'customerReviewCount', 'customerReviewAverage', 'priceUpdateDate', 'itemUpdateDate', 'class', 'classId', 'subclass', 'subclassId', 'department', 'departmentId', 'images', 'image', 'color']
